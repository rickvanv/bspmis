# %%
file = open("/home/rick/CLionProjects/ParallelAlgorithms/mis/data/ca-GrQc/ca-GrQc.mtx-P4", "r")

# %%
import re

# %%
file
# Out:
# <_io.TextIOWrapper name='/home/rick/CLionProjects/ParallelAlgorithms/mis/data/ca-GrQc/ca-GrQc.mtx-P4' mode='r' encoding='UTF-8'>

# %%
print(file)
# Out:
# <_io.TextIOWrapper name='/home/rick/CLionProjects/ParallelAlgorithms/mis/data/ca-GrQc/ca-GrQc.mtx-P4' mode='r' encoding='UTF-8'>

# %%
print(file.read())
# Out:
# %%MatrixMarket distributed-matrix coordinate pattern general
# %-------------------------------------------------------------------------------
# % UF Sparse Matrix Collection, Tim Davis
# % http://www.cise.ufl.edu/research/sparse/matrices/SNAP/ca-GrQc
# % name: SNAP/ca-GrQc
# % [Collaboration network of Arxiv General Relativity]
# % id: 2297
# % date: 2003
# % author: J. Leskovec, J. Kleinberg and C. Faloutsos
# % ed: J. Leskovec
# % fields: name title A id date author ed kind notes aux
# % aux: nodename
# % kind: undirected graph
# %-------------------------------------------------------------------------------
# % notes:
# % Networks from SNAP (Stanford Network Analysis Platform) Network Data Sets,
# % Jure Leskovec http://snap.stanford.edu/data/index.html
# % email jure at cs.stanford.edu
# %
# % General Relativity and Quantum Cosmology collaboration network
# %
# % Dataset information
# %
# % Arxiv GR-QC (General Relativity and Quantum Cosmology) collaboration network is
# ...

# %%
with open("/home/rick/CLionProjects/ParallelAlgorithms/mis/data/ca-GrQc/ca-GrQc.mtx-P4", "r") as file:
    lines = file.readlines()
    for line in lines:
        if line[0] != "%":
            line_split = re.split(" |\n", line)
            if (len(line_split) >2) & (line_split[0] == line_split[1]):
                print(line_split[0])
# Out:
# 5242
# 1
# 963
# 1365
# 2450
# 2873
# 3264
# 5150
# 264
# 2250
# 2253
# 3660
# 917

# %%
string = "8 8\n"

# %%
string_split = re.split(" |\n", string)

# %%
string_split
# Out:
# ['8', '8', '']

# %%
string_split_2
# Out:
# [['8'], ['8', '']]
